# %% [markdown]
# [plotly stacked bar charts](https://plotly.com/python/horizontal-bar-charts/)

# %% [markdown]
# Software skills

# %%
import plotly.graph_objects as go

top_labels = ['Strongly<br>agree', 'Agree']

colors = ['#6e57e0', '#c1b6fc']

x_data = [[70,30],
          [80, 20],
          [75, 25],
          [30, 70],
          [50, 50],
          [90, 10],
          [75, 25],
          [75, 25]]

y_data = ['VBA',
          'Business Objects',
          'Tableau',
          'CSS',
          'HTML',
          'Excel',
          'SQL',
          'Python']

fig = go.Figure()

for i in range(0, len(x_data[0])):
    for xd, yd in zip(x_data, y_data):
        fig.add_trace(go.Bar(
            x=[xd[i]], y=[yd],
            orientation='h',
            width=0.3,  # Change the width of the bars
            marker=dict(
                color=colors[i],
                line=dict(color='rgb(248, 248, 249)', width=1)
            )
        ))

fig.update_layout(
    xaxis=dict(
        showgrid=False,
        showline=False,
        showticklabels=False,
        zeroline=False,
        domain=[0.15, 1]
    ),
    yaxis=dict(
        showgrid=False,
        showline=False,
        showticklabels=False,
        zeroline=False,
    ),
    barmode='stack',
    paper_bgcolor='#fbfbfe',
    plot_bgcolor='#fbfbfe',
    margin=dict(l=0, r=0, t=0, b=0),
    showlegend=False,
)

annotations = []

for yd, xd in zip(y_data, x_data):
    # labeling the y-axis
    annotations.append(dict(xref='paper', yref='y',
                            x=0.14, y=yd,
                            xanchor='right',
                            text=str(yd),
                            font=dict(family='Arial', size=15,
                                      color='rgb(67, 67, 67)'),
                            showarrow=False, align='right'))
    # labeling the first percentage of each bar (x_axis)
    annotations.append(dict(xref='x', yref='y',
                            x=xd[0] / 2, y=yd,
                            text=str(xd[0]) + '%',
                            font=dict(family='Arial', size=14,
                                      color='rgb(248, 248, 255)'),
                            showarrow=False))

fig.update_layout(annotations=annotations)

fig.show()

# %%
# Export method for embedding html into personal website
with open('skills_software.html', 'w') as f:
    f.write(fig.to_html(include_plotlyjs='cdn'))

# %% [markdown]
# Data Analysis

# %%
import plotly.graph_objects as go

top_labels = ['Strongly<br>agree', 'Agree']

colors = ['#6e57e0', '#c1b6fc']

x_data = [[70, 30],
          [70, 30],
          [70, 30],
          [70, 30],
          [80, 20],
          [70, 30],
          [70, 30],
          [70, 30],
          [70, 30],
          [80, 20],
          [85, 15],
          [75, 25],
          [80, 20]]

y_data = ['Multi-Variate A/B',
          'Tensorflow',
          'NLP',
          'Hypothesis Testing',
          'A/B Testing',
          'Casual Impacts',
          'Matching',
          'RFM Segmentation',
          'Gaussian Mixture', 
          'Time Series Forecasting',
          'Data Viz',
          'Machine Learning',
          'Regression',
          'Exploratory Data Analysis']

fig = go.Figure()

for i in range(0, len(x_data[0])):
    for xd, yd in zip(x_data, y_data):
        fig.add_trace(go.Bar(
            x=[xd[i]], y=[yd],
            orientation='h',
            width=0.3,  # Change the width of the bars
            marker=dict(
                color=colors[i],
                line=dict(color='rgb(248, 248, 249)', width=1)
            )
        ))

fig.update_layout(
    xaxis=dict(
        showgrid=False,
        showline=False,
        showticklabels=False,
        zeroline=False,
        domain=[0.15, 1]
    ),
    yaxis=dict(
        showgrid=False,
        showline=False,
        showticklabels=False,
        zeroline=False,
    ),
    barmode='stack',
    paper_bgcolor='#fbfbfe',
    plot_bgcolor='#fbfbfe',
    margin=dict(l=0, r=0, t=0, b=0),
    showlegend=False,
)

annotations = []

for yd, xd in zip(y_data, x_data):
    # labeling the y-axis
    annotations.append(dict(xref='paper', yref='y',
                            x=0.14, y=yd,
                            xanchor='right',
                            text=str(yd),
                            font=dict(family='Arial', size=15,
                                      color='rgb(67, 67, 67)'),
                            showarrow=False, align='right'))
    # labeling the first percentage of each bar (x_axis)
    annotations.append(dict(xref='x', yref='y',
                            x=xd[0] / 2, y=yd,
                            text=str(xd[0]) + '%',
                            font=dict(family='Arial', size=14,
                                      color='rgb(248, 248, 255)'),
                            showarrow=False))

fig.update_layout(annotations=annotations)


fig.show()

# %%
# Export method for embedding html into personal website
with open('skills_data.html', 'w') as f:
    f.write(fig.to_html(include_plotlyjs='cdn'))

# %% [markdown]
# IE Skills

# %%
import plotly.graph_objects as go

top_labels = ['Strongly<br>agree', 'Agree']

colors = ['#6e57e0', '#c1b6fc']

x_data = [[90,10],
          [85, 15],
          [85, 15],
          [85, 15],
          [85, 15],
          [90, 10],
          [85, 15],
          [85, 15]]

y_data = ['Crew Planning',
          'Precedence Network',
          'Cost Forecasting',
          'Line Balancing',
          'Capacity, Staffing',
          'Metric Reporting',
          'Impact assessments',
          'CI, A3']

fig = go.Figure()

for i in range(0, len(x_data[0])):
    for xd, yd in zip(x_data, y_data):
        fig.add_trace(go.Bar(
            x=[xd[i]], y=[yd],
            orientation='h',
            width=0.3,  # Change the width of the bars
            marker=dict(
                color=colors[i],
                line=dict(color='rgb(248, 248, 249)', width=1)
            )
        ))

fig.update_layout(
    xaxis=dict(
        showgrid=False,
        showline=False,
        showticklabels=False,
        zeroline=False,
        domain=[0.15, 1]
    ),
    yaxis=dict(
        showgrid=False,
        showline=False,
        showticklabels=False,
        zeroline=False,
    ),
    barmode='stack',
    paper_bgcolor='#fbfbfe',
    plot_bgcolor='#fbfbfe',
    margin=dict(l=0, r=0, t=0, b=0),
    showlegend=False,
)

annotations = []

for yd, xd in zip(y_data, x_data):
    # labeling the y-axis
    annotations.append(dict(xref='paper', yref='y',
                            x=0.14, y=yd,
                            xanchor='right',
                            text=str(yd),
                            font=dict(family='Arial', size=15,
                                      color='rgb(67, 67, 67)'),
                            showarrow=False, align='right'))
    # labeling the first percentage of each bar (x_axis)
    annotations.append(dict(xref='x', yref='y',
                            x=xd[0] / 2, y=yd,
                            text=str(xd[0]) + '%',
                            font=dict(family='Arial', size=14,
                                      color='rgb(248, 248, 255)'),
                            showarrow=False))

fig.update_layout(annotations=annotations)


fig.show()

# %%
# Export method for embedding html into personal website
with open('skills_ie.html', 'w') as f:
    f.write(fig.to_html(include_plotlyjs='cdn'))

# %% [markdown]
# <hr>

# %%
import plotly.graph_objects as go

top_labels = ['Strongly<br>agree', 'Agree']

colors = ['#6e57e0', '#c1b6fc']

x_data = [[80, 20],
          [75, 25],
          [30, 70],
          [50, 50],
          [90, 10],
          [75, 25],
          [75, 25]]

y_data = ['Business Objects',
          'Tableau',
          'CSS',
          'HTML',
          'Excel',
          'SQL',
          'Python']

fig = go.Figure()

for i in range(0, len(x_data[0])):
    for xd, yd in zip(x_data, y_data):
        fig.add_trace(go.Bar(
            x=[xd[i]], y=[yd],
            orientation='h',
            width=0.15,  # Change the width of the bars
            marker=dict(
                color=colors[i],
                line=dict(color='rgb(248, 248, 249)', width=1)
            )
        ))

fig.update_layout(
    xaxis=dict(
        showgrid=False,
        showline=False,
        showticklabels=False,
        zeroline=False,
        domain=[0.1, 1]
    ),
    yaxis=dict(
        showgrid=False,
        showline=False,
        showticklabels=False,
        zeroline=False,
    ),
    barmode='stack',
    paper_bgcolor='#fbfbfe',
    plot_bgcolor='#fbfbfe',
    margin=dict(l=0, r=0, t=0, b=0),
    showlegend=False,
)

annotations = []

for yd, xd in zip(y_data, x_data):
    # labeling the y-axis
    annotations.append(dict(xref='paper', yref='y',
                            x=0.14, y=yd,
                            xanchor='right',
                            yanchor='bottom',
                            text=str(yd),
                            font=dict(family='Arial', size=15,
                                      color='rgb(67, 67, 67)'),
                            showarrow=False, align='right'))
    # labeling the first percentage of each bar (x_axis)
    annotations.append(dict(xref='x', yref='y',
                            x=xd[0] / 2, y=yd,
                            text=str(xd[0]) + '%',
                            yanchor='bottom',
                            font=dict(family='Arial', size=14,
                                      color='rgb(67, 67, 67)'),
                            showarrow=False))

fig.update_layout(annotations=annotations)

fig.show()

# %%
import plotly.graph_objects as go

# Create a bar chart with custom widths
fig = go.Figure(go.Bar(
    x=[20, 14, 23],
    y=['giraffes', 'orangutans', 'monkeys'],
    orientation='h',
    width=[0.5, 0.3, 0.7]  # Specify custom widths for each bar
))

fig.show()
