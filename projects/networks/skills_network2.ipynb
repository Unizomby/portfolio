# %% [markdown]
# # Skills Network Diagram

# %%
import numpy as np
import pandas as pd 
import networkx as nx
from pyvis.network import Network
from IPython.core.display import HTML

# %%
relationships_df = pd.read_excel('skill_node_attributes.xlsx', sheet_name='relationships')
relationships_df.head(1)
# Out:
#   Skill Successor
# 0   CSS      HTML

# %%
nodes_df = pd.read_excel('skill_node_attributes.xlsx', sheet_name='nodes_attributes')
nodes_df.head(1)
# Out:
#     skill_node  size    color
# 0  A/B Testing    11  #bb9ef7

# %%
G = nx.Graph()
G = nx.from_pandas_edgelist(relationships_df, source='Skill', target='Successor')

# %%
net = Network(notebook=True, cdn_resources='in_line')
net.from_nx(G)
# net.show_buttons()
net.set_options(
    """
    const options = {
  
  "physics": {
    "maxVelocity": 1,
    "minVelocity": 0.75
  }
}
    """
)
net.show('skills_diagram2.html')
# display(HTML('buckey2.html'))
# Out:
# skills_diagram2.html
#         <iframe
#             width="100%"
#             height="600px"
#             src="skills_diagram2.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import numpy as np
import pandas as pd 
import networkx as nx
from pyvis.network import Network
from IPython.display import display, HTML

# Load data from Excel
relationships_df = pd.read_excel('skill_node_attributes.xlsx', sheet_name='relationships')
nodes_df = pd.read_excel('skill_node_attributes.xlsx', sheet_name='nodes_attributes')

# Create graph from relationships
G = nx.Graph()
G = nx.from_pandas_edgelist(relationships_df, source='Skill', target='Successor')

# Initialize pyvis network
net = Network(notebook=True, cdn_resources='in_line')

# Add nodes with attributes from nodes_df
for node in G.nodes():
    # Fetch the corresponding row in nodes_df for node attributes
    node_data = nodes_df[nodes_df['skill_node'] == node]
    
    if not node_data.empty:
        size = node_data['size'].values[0]
        color = node_data['color'].values[0]
        net.add_node(node, title=node, size=size, color=color)
    else:
        # Default size and color if not in nodes_df
        net.add_node(node, title=node, size=10, color='#97C2FC')

# Add edges from G to pyvis network
for edge in G.edges():
    net.add_edge(edge[0], edge[1])

# Custom options (physics settings)
net.set_options(
    """
    const options = {
        "physics": {
            "maxVelocity": 1,
            "minVelocity": 0.75
        }
    }
    """
)

# Show the network
net.show('skills_diagram2.html')
# Out:
# skills_diagram2.html
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 48
#      36 net.set_options(
#      37     """
#      38     const options = {
#    (...)
#      44     """
#      45 )
#      47 # Show the network
# ---> 48 net.show('skills_diagram2.html')
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyvis/network.py:546, in Network.show(self, name, local, notebook)
#     544 print(name)
#     545 if notebook:
# --> 546     self.write_html(name, open_browser=False,notebook=True)
#     547 else:
#     548     self.write_html(name, open_browser=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyvis/network.py:515, in Network.write_html(self, name, local, notebook, open_browser)
#     513 getcwd_name = name
#     514 check_html(getcwd_name)
# ...

# %%
import numpy as np
import pandas as pd 
import networkx as nx
from pyvis.network import Network
from IPython.display import display, HTML

# Load data from Excel
relationships_df = pd.read_excel('skill_node_attributes.xlsx', sheet_name='relationships')
nodes_df = pd.read_excel('skill_node_attributes.xlsx', sheet_name='nodes_attributes')

# Create graph from relationships
G = nx.Graph()
G = nx.from_pandas_edgelist(relationships_df, source='Skill', target='Successor')

# Initialize pyvis network
net = Network(notebook=True, cdn_resources='in_line')

# Add nodes with attributes from nodes_df
for node in G.nodes():
    # Fetch the corresponding row in nodes_df for node attributes
    node_data = nodes_df[nodes_df['skill_node'] == node]
    
    if not node_data.empty:
        size = int(node_data['size'].values[0])  # Convert to standard int
        color = str(node_data['color'].values[0])  # Ensure it's a string
        net.add_node(node, title=node, size=size, color=color)
    else:
        # Default size and color if not in nodes_df
        net.add_node(node, title=node, size=10, color='#97C2FC')

# Add edges from G to pyvis network
for edge in G.edges():
    net.add_edge(edge[0], edge[1])


# Show the network
net.show('skills_diagram2.html')
# Out:
# skills_diagram2.html
#         <iframe
#             width="100%"
#             height="600px"
#             src="skills_diagram2.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
